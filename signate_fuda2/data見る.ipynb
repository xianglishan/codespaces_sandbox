# %% [markdown]
# # data

# %%
# !aws s3 ls s3://xianglishan-sandbox/signate-fuda2/
# Out:
# 2024-01-22 11:59:03     338464 sample_submission.csv
# 2024-01-22 11:59:03    4842723 test.csv
# 2024-01-22 11:59:03    4916051 train.csv

# %%
TRAIN_S3_URI = "s3://xianglishan-sandbox/signate-fuda2/train.csv"

# %%
import numpy as np
import pandas as pd
import os

# %%
train = pd.read_csv(TRAIN_S3_URI)
train
# Out:
#        Unnamed: 0  Term  NoEmp  NewExist  CreateJob  RetainedJob  \
# 0               0   163     21       1.0          0            0
# 1               1    84      6       1.0          4            0
# 2               2   242     45       1.0          4           90
# 3               3   237      4       1.0          0            0
# 4               4   184      0       1.0          0            0
# ...           ...   ...    ...       ...        ...          ...
# 42302       42302   283     14       1.0          0            0
# 42303       42303    53      2       1.0          0            0
# 42304       42304    59      6       2.0          0            0
# 42305       42305   295     18       1.0          0            8
# 42306       42306    84      4       1.0          0            8
#
#        FranchiseCode RevLineCr LowDoc DisbursementDate  ...  Sector  \
# 0                  1         N      N        31-Jan-98  ...       0
# ...
